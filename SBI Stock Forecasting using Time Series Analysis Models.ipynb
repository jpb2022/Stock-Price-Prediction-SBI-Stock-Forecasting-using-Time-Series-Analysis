# %% [markdown]
# ### Project Name:   Forecasting Future SBI Stock Price with Time Series Analysis\SBI Stock Forecasting using Time Series Analysis Models

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error as mse
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\JITENDRA\Downloads\SBIN Stock Price data.csv")
df
# Out:
#             Date        Open        High         Low       Close    Volume
# 0     03-01-2017  239.601049  241.957775  236.753338  240.484817  15963085
# 1     04-01-2017  241.368600  241.957774  237.833497  238.520874  11225978
# 2     05-01-2017  240.583016  241.466784  239.306450  240.926712  11970913
# 3     06-01-2017  241.564985  244.510899  241.073999  241.466782  12354302
# 4     09-01-2017  241.957764  243.872620  241.564981  242.596054   8329253
# ...          ...         ...         ...         ...         ...       ...
# 1090  08-06-2021  432.250000  432.500000  424.000000  427.200012  31113823
# 1091  09-06-2021  427.500000  432.299988  418.200012  421.450012  27784834
# 1092  10-06-2021  424.899994  433.299988  422.399994  432.250000  27397712
# 1093  11-06-2021  434.850006  435.500000  425.250000  429.600006  26831924
# 1094  14-06-2021  427.000000  432.450012  416.700012  430.350006  30106015
#
# [1095 rows x 6 columns]

# %%
df['Date'] = pd.to_datetime(df.Date,dayfirst=True)

# %%
df
# Out:
#            Date        Open        High         Low       Close    Volume
# 0    2017-01-03  239.601049  241.957775  236.753338  240.484817  15963085
# 1    2017-01-04  241.368600  241.957774  237.833497  238.520874  11225978
# 2    2017-01-05  240.583016  241.466784  239.306450  240.926712  11970913
# 3    2017-01-06  241.564985  244.510899  241.073999  241.466782  12354302
# 4    2017-01-09  241.957764  243.872620  241.564981  242.596054   8329253
# ...         ...         ...         ...         ...         ...       ...
# 1090 2021-06-08  432.250000  432.500000  424.000000  427.200012  31113823
# 1091 2021-06-09  427.500000  432.299988  418.200012  421.450012  27784834
# 1092 2021-06-10  424.899994  433.299988  422.399994  432.250000  27397712
# 1093 2021-06-11  434.850006  435.500000  425.250000  429.600006  26831924
# 1094 2021-06-14  427.000000  432.450012  416.700012  430.350006  30106015
#
# [1095 rows x 6 columns]

# %%
data = df.drop(['Date'], axis=1)
data.index = df.Date

# %%
data
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2017-01-03  239.601049  241.957775  236.753338  240.484817  15963085
# 2017-01-04  241.368600  241.957774  237.833497  238.520874  11225978
# 2017-01-05  240.583016  241.466784  239.306450  240.926712  11970913
# 2017-01-06  241.564985  244.510899  241.073999  241.466782  12354302
# 2017-01-09  241.957764  243.872620  241.564981  242.596054   8329253
# ...                ...         ...         ...         ...       ...
# 2021-06-08  432.250000  432.500000  424.000000  427.200012  31113823
# 2021-06-09  427.500000  432.299988  418.200012  421.450012  27784834
# 2021-06-10  424.899994  433.299988  422.399994  432.250000  27397712
# 2021-06-11  434.850006  435.500000  425.250000  429.600006  26831924
# 2021-06-14  427.000000  432.450012  416.700012  430.350006  30106015
#
# [1095 rows x 5 columns]

# %%
train_df = data.iloc[:int(df.shape[0]*0.9595), :]
valid_df = data.iloc[int(df.shape[0]*0.9595):, :]

# %%
train_df.shape, valid_df.shape
# Out:
# ((1050, 5), (45, 5))

# %%
df.shape
# Out:
# (1095, 6)

# %% [markdown]
# ### Auto Regressive (AR) model

# %%
train_df
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2017-01-03  239.601049  241.957775  236.753338  240.484817  15963085
# 2017-01-04  241.368600  241.957774  237.833497  238.520874  11225978
# 2017-01-05  240.583016  241.466784  239.306450  240.926712  11970913
# 2017-01-06  241.564985  244.510899  241.073999  241.466782  12354302
# 2017-01-09  241.957764  243.872620  241.564981  242.596054   8329253
# ...                ...         ...         ...         ...       ...
# 2021-03-31  357.003939  364.484889  354.675461  360.967346  38651025
# 2021-04-01  364.336282  368.497842  359.778357  367.259277  31883453
# 2021-04-05  364.138102  365.822562  345.856870  350.315704  51743981
# 2021-04-06  352.446051  353.734147  346.104575  347.343140  44147709
# 2021-04-07  348.036751  359.877444  344.420148  355.269958  48023602
#
# [1050 rows x 5 columns]

# %%
len(valid_df), len(train_df)
# Out:
# (45, 1050)

# %%
len(valid_df), len(train_df)
# Out:
# (45, 1050)

# %%
from statsmodels.tsa.ar_model import AutoReg

# fit model
model = AutoReg(train_df['Close'], lags=1)
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094)
print(yhat)
# Out:
# 1050    354.767843
# 1051    354.269561
# 1052    353.775082
# 1053    353.284379
# 1054    352.797421
# 1055    352.314180
# 1056    351.834628
# 1057    351.358738
# 1058    350.886479
# 1059    350.417826
# 1060    349.952751
# 1061    349.491226
# 1062    349.033224
# 1063    348.578718
# 1064    348.127682
# 1065    347.680089
# 1066    347.235912
# 1067    346.795127
# 1068    346.357706
# 1069    345.923624
# 1070    345.492856
# 1071    345.065376
# 1072    344.641160
# 1073    344.220182
# 1074    343.802418
# 1075    343.387842
# 1076    342.976432
# 1077    342.568162
# 1078    342.163008
# 1079    341.760948
# 1080    341.361957
# 1081    340.966011
# 1082    340.573088
# 1083    340.183165
# 1084    339.796218
# 1085    339.412225
# 1086    339.031163
# 1087    338.653010
# 1088    338.277744
# 1089    337.905342
# 1090    337.535783
# 1091    337.169046
# 1092    336.805108
# 1093    336.443948
# 1094    336.085545
# dtype: float64
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)

# %%
yhat.index = valid_df.index

# %%
mse(yhat, valid_df['Close'])
# Out:
# 2950.2350574664265

# %%
plt.figure(figsize=(20,10))
plt.plot(train_df['Close'], label='Train')
plt.plot(valid_df['Close'], label='Actual')
plt.plot(yhat, label='Predicted')
plt.xlabel("Date")
plt.ylabel("Stock prices")
plt.title('Close price', fontsize = 20)
#plt.legend()
plt.show()

# %% [markdown]
# ### Moving Average (MA)

# %%
# MA example
from statsmodels.tsa.arima.model import ARIMA

# fit model
model = ARIMA(train_df['Close'], order=(0,0,1))
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094)
print(yhat)

# model = AutoReg(train_df['Close'], lags=1)
# model_fit = model.fit()
# # make prediction
# yhat = model_fit.predict(982, 1227)
# print(yhat)
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 1050    307.215471
# 1051    275.254045
# 1052    275.254045
# 1053    275.254045
# 1054    275.254045
# 1055    275.254045
# 1056    275.254045
# 1057    275.254045
# 1058    275.254045
# 1059    275.254045
# 1060    275.254045
# 1061    275.254045
# 1062    275.254045
# 1063    275.254045
# 1064    275.254045
# 1065    275.254045
# 1066    275.254045
# 1067    275.254045
# 1068    275.254045
# 1069    275.254045
# 1070    275.254045
# 1071    275.254045
# 1072    275.254045
# 1073    275.254045
# 1074    275.254045
# 1075    275.254045
# 1076    275.254045
# 1077    275.254045
# 1078    275.254045
# 1079    275.254045
# 1080    275.254045
# 1081    275.254045
# 1082    275.254045
# 1083    275.254045
# 1084    275.254045
# 1085    275.254045
# 1086    275.254045
# 1087    275.254045
# 1088    275.254045
# 1089    275.254045
# 1090    275.254045
# 1091    275.254045
# 1092    275.254045
# 1093    275.254045
# 1094    275.254045
# Name: predicted_mean, dtype: float64
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
yhat.index = valid_df.index

mse(yhat, valid_df['Close'])
# Out:
# 11970.58469635856

# %%
plt.figure(figsize=(20,12))
plt.plot(train_df['Close'], label='Train')
plt.plot(valid_df['Close'], label='Actual')
plt.plot(yhat, label='Predicted')
plt.ylabel("Stock prices")
plt.title('Close price', fontsize = 20)
plt.legend()
plt.show()

# %% [markdown]
# ## Autoregressive Integrated Moving Average (ARIMA) will be used from after v_0.12
#
# #### Autoregressive Moving Average (ARMA) has been Depricated!

# %% [markdown]
# Note: statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# Note: statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.

# %% [markdown]
# ### ARIMA(0, 1, 2)

# %%
from statsmodels.tsa.arima.model import ARIMA

# fit model
model = ARIMA(train_df['Close'], order=(0, 1, 2))
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094)
#print(yhat)

yhat.index = valid_df.index
mse(yhat, valid_df['Close'])
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 1932.7384883758925

# %% [markdown]
# ### ARIMA(0, 2, 1)

# %%
from statsmodels.tsa.arima.model import ARIMA

# fit model
model = ARIMA(train_df['Close'], order=(0, 2, 1))
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094)
print(yhat)
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 1050    355.383160
# 1051    355.496362
# 1052    355.609564
# 1053    355.722765
# 1054    355.835967
# 1055    355.949169
# 1056    356.062370
# 1057    356.175572
# 1058    356.288774
# 1059    356.401976
# 1060    356.515177
# 1061    356.628379
# 1062    356.741581
# 1063    356.854782
# 1064    356.967984
# 1065    357.081186
# 1066    357.194388
# 1067    357.307589
# 1068    357.420791
# 1069    357.533993
# 1070    357.647194
# 1071    357.760396
# 1072    357.873598
# 1073    357.986800
# 1074    358.100001
# 1075    358.213203
# 1076    358.326405
# 1077    358.439606
# 1078    358.552808
# 1079    358.666010
# 1080    358.779212
# 1081    358.892413
# 1082    359.005615
# 1083    359.118817
# 1084    359.232018
# 1085    359.345220
# 1086    359.458422
# 1087    359.571623
# 1088    359.684825
# 1089    359.798027
# 1090    359.911229
# 1091    360.024430
# 1092    360.137632
# 1093    360.250834
# 1094    360.364035
# Name: predicted_mean, dtype: float64
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
yhat.index = valid_df.index

mse(yhat, valid_df['Close'])
# Out:
# 1730.2576422143215

# %%
plt.figure(figsize=(20,12))
plt.plot(train_df['Close'], label='Train')
plt.plot(valid_df['Close'], label='Actual')
plt.plot(yhat, label='Predicted')
plt.ylabel("Stock prices")
plt.title('Close price', fontsize = 20)
plt.grid()

# %% [markdown]
# ### ARIMA(0, 2, 2)

# %%
from statsmodels.tsa.arima.model import ARIMA

# fit model
model = ARIMA(train_df['Close'], order=(0, 2, 2))
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094)
#print(yhat)

yhat.index = valid_df.index
mse(yhat, valid_df['Close'])
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 1726.5324336690812

# %% [markdown]
# ### ARIMA(3, 1, 0)

# %%
from statsmodels.tsa.arima.model import ARIMA

# fit model
model = ARIMA(train_df['Close'], order=(3, 1, 0))
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094)
#print(yhat)

yhat.index = valid_df.index
mse(yhat, valid_df['Close'])
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 1926.9823195189153

# %% [markdown]
# ### ARIMA(0, 3, 2)

# %%
from statsmodels.tsa.arima.model import ARIMA

# fit model
model = ARIMA(train_df['Close'], order=(0, 3, 2))
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094)
#print(yhat)

yhat.index = valid_df.index
mse(yhat, valid_df['Close'])
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 883.7960703245818

# %%
plt.figure(figsize=(20,12))
plt.plot(train_df['Close'], label='Train')
plt.plot(valid_df['Close'], label='Actual')
plt.plot(yhat, label='Predicted')
plt.ylabel("Stock prices")
plt.title('Close price', fontsize = 20)
plt.grid()

# %% [markdown]
# ### ARIMA(0, 3, 3)

# %%
from statsmodels.tsa.arima.model import ARIMA

# fit model
model = ARIMA(train_df['Close'], order=(0, 3, 3))
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094)
#print(yhat)

yhat.index = valid_df.index
mse(yhat, valid_df['Close'])
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 681.6554177858013

# %%
from statsmodels.tsa.arima.model import ARIMA

# fit model
model = ARIMA(train_df['Close'], order=(1,1,0))
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094)
#print(yhat)

yhat.index = valid_df.index
mse(yhat, valid_df['Close'])
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 1939.5774334210903

# %% [markdown]
# ### ARIMA(1,1,1)

# %%
from statsmodels.tsa.arima.model import ARIMA

# fit model
model = ARIMA(train_df['Close'], order=(1, 1, 1))
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094, typ='levels')
print(yhat)
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 1050    355.119236
# 1051    354.984630
# 1052    354.864417
# 1053    354.757058
# 1054    354.661179
# 1055    354.575552
# 1056    354.499081
# 1057    354.430786
# 1058    354.369795
# 1059    354.315325
# 1060    354.266679
# 1061    354.223235
# 1062    354.184437
# 1063    354.149787
# 1064    354.118842
# 1065    354.091206
# 1066    354.066525
# 1067    354.044483
# 1068    354.024798
# 1069    354.007218
# 1070    353.991518
# 1071    353.977496
# 1072    353.964974
# 1073    353.953791
# 1074    353.943803
# 1075    353.934884
# 1076    353.926918
# 1077    353.919804
# 1078    353.913451
# 1079    353.907777
# 1080    353.902710
# 1081    353.898184
# 1082    353.894143
# 1083    353.890533
# 1084    353.887310
# 1085    353.884431
# 1086    353.881860
# 1087    353.879564
# 1088    353.877514
# 1089    353.875682
# 1090    353.874047
# 1091    353.872586
# 1092    353.871282
# 1093    353.870117
# 1094    353.869077
# Name: predicted_mean, dtype: float64
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
yhat.index = valid_df.index

mse(yhat, valid_df['Close'])
# Out:
# 2017.7686720847025

# %%
plt.figure(figsize=(20,12))
plt.plot(train_df['Close'], label='Train')
plt.plot(valid_df['Close'], label='Actual')
plt.plot(yhat, label='Predicted')
plt.ylabel("Stock prices")
plt.title('Close price', fontsize = 20)
plt.legend()
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA

# fit model
model = ARIMA(train_df['Close'], order=(0, 3, 3))
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094)
#print(yhat)

yhat.index = valid_df.index
mse(yhat, valid_df['Close'])
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 681.6554177858013

# %% [markdown]
# ### ARIMA(2,1,1)

# %%
from statsmodels.tsa.arima.model import ARIMA

# fit model
model = ARIMA(train_df['Close'], order=(2, 1, 1))
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094, typ='levels')
print(yhat)
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 1050    355.401931
# 1051    355.606054
# 1052    355.580857
# 1053    355.590163
# 1054    355.588137
# 1055    355.588686
# 1056    355.588551
# 1057    355.588586
# 1058    355.588577
# 1059    355.588579
# 1060    355.588579
# 1061    355.588579
# 1062    355.588579
# 1063    355.588579
# 1064    355.588579
# 1065    355.588579
# 1066    355.588579
# 1067    355.588579
# 1068    355.588579
# 1069    355.588579
# 1070    355.588579
# 1071    355.588579
# 1072    355.588579
# 1073    355.588579
# 1074    355.588579
# 1075    355.588579
# 1076    355.588579
# 1077    355.588579
# 1078    355.588579
# 1079    355.588579
# 1080    355.588579
# 1081    355.588579
# 1082    355.588579
# 1083    355.588579
# 1084    355.588579
# 1085    355.588579
# 1086    355.588579
# 1087    355.588579
# 1088    355.588579
# 1089    355.588579
# 1090    355.588579
# 1091    355.588579
# 1092    355.588579
# 1093    355.588579
# 1094    355.588579
# Name: predicted_mean, dtype: float64
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
yhat.index = valid_df.index

mse(yhat, valid_df['Close'])
# Out:
# 1931.3595788406312

# %%
plt.figure(figsize=(20,12))
plt.plot(train_df['Close'], label='Train')
plt.plot(valid_df['Close'], label='Actual')
plt.plot(yhat, label='Predicted')
plt.ylabel("Stock prices")
plt.title('Close price', fontsize = 20)
plt.legend()
plt.show()

# %% [markdown]
# ### ARIMA(2,1,2)

# %%
from statsmodels.tsa.arima.model import ARIMA

# fit model
model = ARIMA(train_df['Close'], order=(2, 1, 2))
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094, typ='levels')
#print(yhat)

yhat.index = valid_df.index
mse(yhat, valid_df['Close'])
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 1944.125167698084

# %% [markdown]
# ### ARIMA(3,1,1)

# %%
from statsmodels.tsa.arima.model import ARIMA

# fit model
model = ARIMA(train_df['Close'], order=(3, 1, 1))
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094, typ='levels')
#print(yhat)

yhat.index = valid_df.index
mse(yhat, valid_df['Close'])
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 1926.988976474551

# %% [markdown]
# ### ARIMA(3,1,2)

# %%
from statsmodels.tsa.arima.model import ARIMA

# fit model
model = ARIMA(train_df['Close'], order=(3, 1, 2))
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094, typ='levels')
#print(yhat)

yhat.index = valid_df.index
mse(yhat, valid_df['Close'])
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 1917.784845750688

# %% [markdown]
# ### ARIMA(3,1,3)

# %%
from statsmodels.tsa.arima.model import ARIMA

# fit model
model = ARIMA(train_df['Close'], order=(3, 1, 3))
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094, typ='levels')
#print(yhat)

yhat.index = valid_df.index
mse(yhat, valid_df['Close'])
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 1807.9387081001453

# %%
from pmdarima.arima import auto_arima

model_auto = auto_arima(train_df['Close'],exog=train_df['Open'],
                        m = 5, max_p = 5, max_q = 5, max_P = 5, max_Q = 5)
model_auto.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                 1050
# Model:             SARIMAX(0, 1, 0)x(1, 0, 0, 5)   Log Likelihood               -3449.149
# Date:                           Mon, 07 Aug 2023   AIC                           6902.299
# Time:                                   19:12:44   BIC                           6912.210
# Sample:                                        0   HQIC                          6906.057
#                                           - 1050
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L5        0.1141      0.029      3.925      0.000       0.057       0.171
# sigma2        42.0194      0.621     67.681      0.000      40.803      43.236
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.49   Jarque-Bera (JB):             10719.15
# Prob(Q):                              0.48   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.50   Skew:                             1.37
# Prob(H) (two-sided):                  0.00   Kurtosis:                        18.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### Seasonal Autoregressive Integrated Moving-Average (SARIMA)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# fit model
model = SARIMAX(train_df['Close'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
model_fit = model.fit(disp=False)
# make prediction
yhat = model_fit.predict(1050, 1094)
print(yhat)
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 1050    355.544211
# 1051    355.718411
# 1052    358.052240
# 1053    357.655511
# 1054    357.736652
# 1055    357.454212
# 1056    357.453129
# 1057    358.028691
# 1058    358.307772
# 1059    355.866279
# 1060    354.665802
# 1061    355.516970
# 1062    355.467607
# 1063    356.066668
# 1064    358.109314
# 1065    358.885922
# 1066    359.420893
# 1067    358.938252
# 1068    358.612905
# 1069    358.926037
# 1070    358.648797
# 1071    357.573482
# 1072    356.544597
# 1073    356.736935
# 1074    356.661170
# 1075    357.303427
# 1076    359.321632
# 1077    360.210698
# 1078    360.790298
# 1079    360.290655
# 1080    359.936411
# 1081    360.226221
# 1082    359.897911
# 1083    358.951630
# 1084    357.939628
# 1085    358.070868
# 1086    357.993204
# 1087    358.640003
# 1088    360.656334
# 1089    361.556301
# 1090    362.140391
# 1091    361.639412
# 1092    361.282679
# 1093    361.570489
# 1094    361.237552
# Name: predicted_mean, dtype: float64
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
yhat.index = valid_df.index

mse(yhat, valid_df['Close'])
# Out:
# 1716.7120458125817

# %%
plt.figure(figsize=(20,12))
plt.plot(train_df['Close'], label='Train')
plt.plot(valid_df['Close'], label='Actual')
plt.plot(yhat, label='Predicted')
plt.ylabel("Stock prices")
plt.title('Close price', fontsize = 20)
plt.legend()
plt.show()

# %% [markdown]
# ### Seasonal Autoregressive Integrated Moving-Average with Exogenous Regressors (SARIMAX)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# fit model
model = SARIMAX(train_df['Close'], exog=train_df['Open'], order=(1, 1, 1), seasonal_order=(1,1,1,4))
model_fit = model.fit(disp=False)
# make prediction

yhat = model_fit.predict(1050, 1094, exog = valid_df['Open'])
print(yhat)
# Out:
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 1050    356.501014
# 1051    349.349394
# 1052    339.014925
# 1053    328.923607
# 1054    338.129818
# 1055    338.380564
# 1056    322.532485
# 1057    331.819721
# 1058    322.324774
# 1059    327.240144
# 1060    334.413556
# 1061    340.554664
# 1062    352.761899
# 1063    359.984666
# 1064    348.355362
# 1065    346.052344
# 1066    350.797442
# 1067    351.638097
# 1068    352.822093
# 1069    353.808344
# 1070    356.196957
# 1071    351.981026
# 1072    357.534308
# 1073    366.080904
# 1074    360.025524
# 1075    384.529083
# 1076    376.385386
# 1077    382.771878
# 1078    385.160517
# 1079    411.038686
# 1080    408.884349
# 1081    409.085102
# 1082    408.429963
# 1083    424.293146
# 1084    414.676622
# 1085    421.112197
# 1086    425.219094
# 1087    434.635970
# 1088    434.842635
# 1089    433.941583
# 1090    430.560475
# 1091    425.221419
# 1092    422.356197
# 1093    433.693127
# 1094    425.357372
# Name: predicted_mean, dtype: float64
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
yhat.index = valid_df.index



print("MSE for order=(1, 1, 1), seasonal_order=(1,1,1,4) is:    " + str(mse(yhat, valid_df['Close'])))
# Out:
# MSE for order=(1, 1, 1), seasonal_order=(1,1,1,4) is:    46.29688338469084

# %%
plt.figure(figsize=(20,12))
plt.plot(train_df['Close'], label='Train')
plt.plot(valid_df['Close'], label='Actual')
plt.plot(yhat, label='Predicted')
plt.ylabel("Stock prices")
plt.title('Close price', fontsize = 20)
plt.legend()
plt.show()

# %% [markdown]
# ### Simple Exponential Smoothing (SES)

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

model = SimpleExpSmoothing(train_df['Close'])
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(1050, 1094)
print(yhat)
# Out:
# 1050    355.269958
# 1051    355.269958
# 1052    355.269958
# 1053    355.269958
# 1054    355.269958
# 1055    355.269958
# 1056    355.269958
# 1057    355.269958
# 1058    355.269958
# 1059    355.269958
# 1060    355.269958
# 1061    355.269958
# 1062    355.269958
# 1063    355.269958
# 1064    355.269958
# 1065    355.269958
# 1066    355.269958
# 1067    355.269958
# 1068    355.269958
# 1069    355.269958
# 1070    355.269958
# 1071    355.269958
# 1072    355.269958
# 1073    355.269958
# 1074    355.269958
# 1075    355.269958
# 1076    355.269958
# 1077    355.269958
# 1078    355.269958
# 1079    355.269958
# 1080    355.269958
# 1081    355.269958
# 1082    355.269958
# 1083    355.269958
# 1084    355.269958
# 1085    355.269958
# 1086    355.269958
# 1087    355.269958
# 1088    355.269958
# 1089    355.269958
# 1090    355.269958
# 1091    355.269958
# 1092    355.269958
# 1093    355.269958
# 1094    355.269958
# dtype: float64
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\JITENDRA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
yhat.index = valid_df.index

mse(yhat, valid_df['Close'])
# Out:
# 1946.057125175247

# %%
plt.figure(figsize=(20,12))
plt.plot(train_df['Close'], label='Train')
plt.plot(valid_df['Close'], label='Actual')
plt.plot(yhat, label='Predicted')
plt.ylabel("Stock prices")
plt.title('Close price', fontsize = 20)
plt.legend()
plt.show()
